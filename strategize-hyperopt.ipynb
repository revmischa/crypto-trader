# %% [markdown]
# ### Dependencies
# This assumes you have `pandas`, `numpy`, `jupyterlab`, `plotly`, `scikit-optimize`, and `pandas-ta` available in your system or virtual environment.
# You also need `ta-lib`, on macOS you can get it with `brew install ta-lib`

# %% [markdown]
# ### Configuration
# Create a file called `.env` with:
# ```env
# EXCHG_API_KEY=d019f019ca0918c0ac80
# EXCHG_SECRET=ba19ca9310de910
# ```

# %%
import sys
# install dependencies
# !{sys.executable} -m pip install -q matplotlib ipywidgets plotly pyjuque
# Out:
# ERROR: Could not find a version that satisfies the requirement sciki (from versions: none)
# ERROR: No matching distribution found for sciki
# WARNING: You are using pip version 21.2.3; however, version 21.3 is available.
# You should consider upgrading via the '/Users/cyber/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/bin/python -m pip install --upgrade pip' command.
# Collecting git+https://github.com/revmischa/pyjuque@patch-1
#   Cloning https://github.com/revmischa/pyjuque (to revision patch-1) to /private/var/folders/kd/1xqhjdy16c31k9ffswc8wbm40000gn/T/pip-req-build-ft6fqcpd
#   Running command git clone -q https://github.com/revmischa/pyjuque /private/var/folders/kd/1xqhjdy16c31k9ffswc8wbm40000gn/T/pip-req-build-ft6fqcpd
# ^C
# ERROR: Operation cancelled by user
# WARNING: You are using pip version 21.2.3; however, version 21.3 is available.
# You should consider upgrading via the '/Users/cyber/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/bin/python -m pip install --upgrade pip' command.

# %%
import time
import os
from pprint import pprint
import logging
import cProfile
from typing import Dict
import datetime
import math
from IPython.display import HTML
from copy import deepcopy
from dotenv import load_dotenv

import numpy as np
import pandas as pd
import pandas_ta as ta
from skopt.plots import plot_evaluations
from skopt import gp_minimize, forest_minimize, dummy_minimize, BayesSearchCV
from skopt.space import Real
from skopt.utils import use_named_args
from skopt import Optimizer
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
import plotly

from pyjuque.Bot import defineBot
from pyjuque.Plotting import PlotData, GetPlotData
from pyjuque.Exchanges.CcxtExchange import CcxtExchange
from pyjuque.Engine.BacktesterSundayTheQuant import Backtester
from pyjuque.Strategies import StrategyTemplate

# %matplotlib inline
PROFILING = True

# connect to your exchange
exchange = CcxtExchange("ftx")

# %%
timeframe = '15s'  # 1 minute timeframe
starting_balance = 1000. # dollars
symbol = 'ETH-PERP'

# configure your exchange here via .env file
load_dotenv()
api_key = os.environ["EXCHG_API_KEY"]
secret = os.environ["EXCHG_SECRET"]
exchange_config = {
    "exchange": {
        "name": "ftx",
        "params": {
            "api_key": api_key,
            "secret": secret,
        },
    },
}

def gen_config(
    StratClass,
    params: Dict[str, float],
    signal_distance,
    take_profit,
    stop_loss_value=80,
    test_run=True,
) -> dict:
    return {
        "name": "simulator",
        "test_run": test_run,
        **exchange_config,
        "symbols": [ symbol ],
        "starting_balance": starting_balance,
        "strategy": {"class": StratClass, "params": params},
        "timeframe": timeframe,
        "entry_settings": {
            "initial_entry_allocation": 5,
            "signal_distance": signal_distance,  # pct under buy signal to place order
            "leverage": 1,
        },
        "exit_settings": {
            "take_profit": take_profit,
            "stop_loss_value": stop_loss_value,
            "exit_on_signal": True,
            "sell_on_end": True,
        },
    }

# %%
# how many units of timeframe (15s) to test back in time
backtest_times = 4 * 60 * 24 * 2#days
backtest_times = 4 * 60 * 12#hours

# utilities
symbol_df_cache: Dict[str, pd.DataFrame] = {
    symbol: exchange.getOHLCV(symbol, timeframe, backtest_times)
}


def backtest(bot_config: dict) -> Backtester:
    bt = Backtester(bot_config)
    results = {}
    for symbol in bot_config["symbols"]:
        # fetch historical exchange data (OHLCV) for symbol
        # backtesting will be performed on this dataset
        if not symbol in symbol_df_cache:
            symbol_df_cache[symbol] = exchange.getOHLCV(symbol, bot_config['timeframe'], backtest_times)
        df = symbol_df_cache[symbol]

        # backtest
        bt.backtest(df)
        results[symbol] = dict(results=bt.return_results(), entries=bt.entries, exits=bt.exits, df=df)
        
    return results

def plot_backtest_results(title, df, entries, exits):
    return PlotData(df, 
        plot_indicators=[
            dict(name = 'slow_ma', title = 'Slow HMA'),
            dict(name = 'fast_ma', title = 'Fast HMA'),
        ],
        signals=[
            dict(name = 'Buy', points = entries), 
            dict(name = 'Sell', points = exits),
        ], 
        add_volume=False,
        plot_title=title,
    )

# %%
# strategy to run
class EMACross(StrategyTemplate):
    """Bollinger Bands x RSI"""

    minimum_period = 100

    def __init__(self, fast_ma_len=3, slow_ma_len=15):
        self.fast_ma_len = fast_ma_len
        self.slow_ma_len = slow_ma_len
        # the minimum number of candles needed to compute our indicators
        self.minimum_period = max(60, slow_ma_len)

    # the bot will call this function with the latest data from the exchange
    # passed through df; this function computes all the indicators needed
    # for the signal
    def setUp(self, df):
        df["slow_ma"] = ta.ema(df["close"], self.slow_ma_len)
        df["fast_ma"] = ta.ema(df["close"], self.fast_ma_len)
        self.dataframe = df

    # the bot will call this function with the latest data and if this
    # returns true, our bot will place an order
    def checkLongSignal(self, i=None):
        """ """
        df = self.dataframe
        if i == None:
            i = len(df) - 1
        if i < 1:
            return False
        if (
            df["low"][i - 1] < df["slow_ma"][i - 1]
            and df["low"][i] > df["slow_ma"][i]
            and df["low"][i] > df["fast_ma"][i]
            and df["fast_ma"][i] > df["slow_ma"][i]
        ):
            return True
        return False

    def checkShortSignal(self, i=None):
        df = self.dataframe
        if i == None:
            i = len(df) - 1
        if i < 1:
            return False
        if (
            (
                df["low"][i - 1] > df["slow_ma"][i - 1]
                or df["fast_ma"][i - 1] > df["slow_ma"][i - 1]
            )
            and df["close"][i] < df["slow_ma"][i]
            and df["close"][i] < df["fast_ma"][i]
            and df["fast_ma"][i] < df["slow_ma"][i]
        ):
            return True
        return False

# %%
# search space
#fast_ma_len = Real(name='fast_ma_len', low=3.0, high=10.0)
#slow_ma_len = Real(name='slow_ma_len', low=5.0, high=40.0)
# number between 0 and 100 - 1% means that when we get a buy signal, 
# we place buy order 1% below current price. if 0, we place a market 
# order immediately upon receiving signal
signal_distance = Real(name='signal_distance', low=0.0, high=3.0)
# take profit value between 0 and infinity, 3% means we place our sell 
# orders 3% above the prices that our buy orders filled at
take_profit = Real(name='take_profit', low=0.01, high=4.0)
dimensions = [signal_distance, take_profit]

def calc_strat_loss(backtest_res) -> dict:
    """Given backtest results, calculate loss.
    
    Loss is a measure of how badly we're doing.
    """
    score = 0
    
    for symbol, symbol_res in backtest_res.items():
        symbol_bt_res = symbol_res['results']
        profit_realised = symbol_bt_res['profit_realised']
        profit_after_fees = symbol_bt_res['profit_after_fees']
        winrate = symbol_bt_res['winrate']

        if profit_after_fees < 0:
            # lost money.
            # bad.
            score -= profit_after_fees + 1

        if profit_after_fees == 0.0:
            # well it's not great but not terrible...
            pass

        # how well we're doing (positive)
        score += profit_after_fees# + winrate/100
        
    if score < 0:
        # not doing so good
        return -1 * score

    # return loss; lower number is better
    return math.pow(0.3, score)

def params_to_bot_config(p):
    params = {**p}
    # strat params
    fast_ma_len = params.pop('fast_ma_len')
    slow_ma_len = params.pop('slow_ma_len')
    bot_config = gen_config(
        StratClass=EMACross, 
        params=dict(fast_ma_len=fast_ma_len, slow_ma_len=slow_ma_len),
        **params
    )
    return bot_config

# %%
ITERATION = 0
@use_named_args(dimensions=dimensions)
def objective(**params):
    """This is our fitness function.
    
    It takes a set of parameters and returns the "loss" - an objective single scalar to minimize.
    """
    bot_config = params_to_bot_config(params)
    
    global ITERATION
    ITERATION += 1

    try:
        backtest_res = backtest(bot_config)
    except Exception as ex:
        if 'Not enough data' in str(ex) or 'TA_BAD_PARAM' in str(ex):
            return 1  # bad input
        raise ex

    return calc_strat_loss(backtest_res)

def opt_ema_strat_sk(n_calls) -> Dict[str, float]:
    opt_res = forest_minimize(func=objective,
                          dimensions=dimensions,
                          n_calls=n_calls, base_estimator="ET",
                          random_state=None)

    _ = plot_evaluations(opt_res, bins=10)
    return opt_res

def opt_ema_strat_sk_parallel(n_calls:int) -> Optimizer:
    optimizer = Optimizer(
        dimensions=dimensions,
        random_state=None,  # random seed
        base_estimator='gp'
    )
    
    start_time = time.time()
    if PROFILING:
        pr = cProfile.Profile()
        pr.enable()

    parallel = 4
    for i in range(int(n_calls / parallel)):
        x = optimizer.ask(n_points=parallel)  # x is a list of n_points points
        print("Grabbing...")
        y = Parallel(n_jobs=parallel)(delayed(objective)(v) for v in x)  # evaluate points in parallel
        optimizer.tell(x, y)
        
    if PROFILING:
        pr.disable()
        pr.dump_stats('profile')
        elapsed = time.time() - start_time
        print(f"{n_calls} calls, elapsed={elapsed:0.2f}s, rate={n_calls/elapsed:0.1f} calls/s")
        
    return optimizer

# %%
optimizer = opt_ema_strat_sk_parallel(n_calls=3000)
# Out:
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# /Users/cyber/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning:
#
# The objective has been evaluated at this point before.
# Grabbing...
# Grabbing...
# Grabbing...
# Grabbing...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/kd/1xqhjdy16c31k9ffswc8wbm40000gn/T/ipykernel_6618/2440190476.py in <module>
# ----> 1 optimizer = opt_ema_strat_sk_parallel(n_calls=3000)
#
# /var/folders/kd/1xqhjdy16c31k9ffswc8wbm40000gn/T/ipykernel_6618/1006652198.py in opt_ema_strat_sk_parallel(n_calls)
#      43     parallel = 4
#      44     for i in range(int(n_calls / parallel)):
# ---> 45         x = optimizer.ask(n_points=parallel)  # x is a list of n_points points
#      46         print("Grabbing...")
#      47         y = Parallel(n_jobs=parallel)(delayed(objective)(v) for v in x)  # evaluate points in parallel
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/skopt/optimizer/optimizer.py in ask(self, n_points, strategy)
#     415                 opt._tell(x, (y_lie, t_lie))
#     416             else:
# --> 417                 opt._tell(x, y_lie)
#     418
#     419         self.cache_ = {(n_points, strategy): X}  # cache_ the result
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/skopt/optimizer/optimizer.py in _tell(self, x, y, fit)
#     534             with warnings.catch_warnings():
#     535                 warnings.simplefilter("ignore")
# --> 536                 est.fit(self.space.transform(self.Xi), self.yi)
#     537
#     538             if hasattr(self, "next_xs_") and self.acq_func == "gp_hedge":
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/skopt/learning/gaussian_process/gpr.py in fit(self, X, y)
#     193                 noise_level=self.noise, noise_level_bounds="fixed"
#     194             )
# --> 195         super(GaussianProcessRegressor, self).fit(X, y)
#     196
#     197         self.noise_ = None
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py in fit(self, X, y)
#     270             optima = [
#     271                 (
# --> 272                     self._constrained_optimization(
#     273                         obj_func, self.kernel_.theta, self.kernel_.bounds
#     274                     )
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py in _constrained_optimization(self, obj_func, initial_theta, bounds)
#     587     def _constrained_optimization(self, obj_func, initial_theta, bounds):
#     588         if self.optimizer == "fmin_l_bfgs_b":
# --> 589             opt_res = scipy.optimize.minimize(
#     590                 obj_func,
#     591                 initial_theta,
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     617                                   **options)
#     618     elif meth == 'l-bfgs-b':
# --> 619         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     620                                 callback=callback, **options)
#     621     elif meth == 'tnc':
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     258         if not np.array_equal(x, self.x):
#     259             self._update_x_impl(x)
# --> 260         self._update_fun()
#     261         self._update_grad()
#     262         return self.f, self.g
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     224     def _update_fun(self):
#     225         if not self.f_updated:
# --> 226             self._update_fun_impl()
#     227             self.f_updated = True
#     228
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     131
#     132         def update_fun():
# --> 133             self.f = fun_wrapped(self.x)
#     134
#     135         self._update_fun_impl = update_fun
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     128         def fun_wrapped(x):
#     129             self.nfev += 1
# --> 130             return fun(x, *args)
#     131
#     132         def update_fun():
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/scipy/optimize/optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py in obj_func(theta, eval_gradient)
#     260             def obj_func(theta, eval_gradient=True):
#     261                 if eval_gradient:
# --> 262                     lml, grad = self.log_marginal_likelihood(
#     263                         theta, eval_gradient=True, clone_kernel=False
#     264                     )
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py in log_marginal_likelihood(self, theta, eval_gradient, clone_kernel)
#     511
#     512         if eval_gradient:
# --> 513             K, K_gradient = kernel(self.X_train_, eval_gradient=True)
#     514         else:
#     515             K = kernel(self.X_train_)
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py in __call__(self, X, Y, eval_gradient)
#     841         if eval_gradient:
#     842             K1, K1_gradient = self.k1(X, Y, eval_gradient=True)
# --> 843             K2, K2_gradient = self.k2(X, Y, eval_gradient=True)
#     844             return K1 + K2, np.dstack((K1_gradient, K2_gradient))
#     845         else:
#
# ~/Library/Caches/pypoetry/virtualenvs/trader-s5F4ixgX-py3.9/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py in __call__(self, X, Y, eval_gradient)
#    1385                     return (
#    1386                         K,
# -> 1387                         self.noise_level * np.eye(_num_samples(X))[:, :, np.newaxis],
#    1388                     )
#    1389                 else:
#
# KeyboardInterrupt:

# %%
# find best
min_loss = 1.0
best_params = None
for i, x in enumerate(optimizer.Xi):
    loss = optimizer.yi[i]
    if loss < min_loss:
        min_loss = loss
        best_params = x
print("Best loss:", min_loss)
print("Best parameters:", best_params)
best_config = dict(zip([d.name for d in dimensions], best_params))
print(best_config)
best_config = params_to_bot_config(best_config)
bt_res = backtest(best_config)
# Out:
# Best loss: 0.28502134190160616
# Best parameters: [10.0, 8.784245565442916, 3.0, 0.2224994829233058, 46.899820255644556]
# {'fast_ma_len': 10.0, 'slow_ma_len': 8.784245565442916, 'signal_distance': 3.0, 'take_profit': 0.2224994829233058, 'stop_loss_value': 46.899820255644556}

# %%
alloc = best_config['entry_settings']['initial_entry_allocation']
entry_exit_marker_size = 15
def fix_series_ts(initial_entry_allocation: float, series:list[tuple]):
    ret = []
    for e in series:
        n = [*e]
        n[0] = pd.to_datetime(n[0] * 10e5)
        n[2] = entry_exit_marker_size
        ret.append(n)
    return ret

# formatting and massaging results
symbol_bt_res = bt_res[symbol]
res = symbol_bt_res['results']
profit = res['profit_after_fees']
initial = res['balance_initial']
bal = res['balance_plus_profits']
print(f"{symbol}: Initial {initial}, profit: {profit:0.3}, return %{(bal/float(initial)*100):.6}")
df = symbol_bt_res['df']

# visualize trades made during backtesting
# date and time columns are broken
df2 = df.drop(columns=['date'])
df2['time'] = pd.to_datetime(df['time'] * 10e5)
# generate plotly figure
fig = plot_backtest_results(
    symbol, 
    df2, 
    fix_series_ts(alloc, symbol_bt_res['entries']), 
    fix_series_ts(alloc, symbol_bt_res['exits'])
)

# will render inline a nice visualization of buy/sell events on a candlestick chart
fig
# Out:
# ETH-PERP: Initial 1000.0, profit: 1.04, return %100.104
# FigureWidget({
#     'data': [{'close': array([3874.5, 3873. , 3874.8, ..., 3807.5, 3807.6, 3807.6]),
#           …

# %%
# trials w/ results
btdf = pd.DataFrame({
    'loss': optimizer.yi, 
    'iteration': range(len(optimizer.yi)),
})
btdf['l'] = btdf['loss']
fig = btdf.plot.scatter('iteration', y=['loss'], logy=False, figsize=(25,6))
